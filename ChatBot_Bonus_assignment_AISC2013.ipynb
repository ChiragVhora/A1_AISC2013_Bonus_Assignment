# %%
#2 Importing Relevant Libraries

import json
import string
import random

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
#3 Loading the Dataset: intents.json

data_file = open('intents.json').read()
data = json.loads(data_file)

data
# Out:
# {'intents': [{'tag': 'hello',
#    'patterns': ['Hello', 'Hi there', 'Good morning', "What's up"],
#    'responses': ['Hey!', 'Hello', 'Hi!', 'Good morning!'],
#    'context': ''},
#   {'tag': 'noanswer',
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'context': ['']},
#   {'tag': 'job',
#    'patterns': ['What is your job', 'What is your work'],
#    'responses': ['My job is to make you feel like everything is okay.',
#     'I work to serve you as well as possible'],
#    'context': ''},
#   {'tag': 'age',
#    'patterns': ['What is your age', 'How old are you', 'When were you born'],
#    'responses': ['I was born in 2021'],
#    'context': ''},
#   {'tag': 'feeling',
#    'patterns': ['How are you today', 'How are you'],
#    'responses': ['I am feeling good, you?',
#     'Very good and you?',
#     "Actually, I'm okay and you?"],
#    'context': ''},
#   {'tag': 'good',
#    'patterns': ['I am good too',
#     'I feel fine',
#     'Good !',
#     'Fine',
#     'I am good',
#     'I am great',
#     'great'],
#    'responses': ['That is perfect!', "So, everything's okay!"],
#    'context': 'feeling'},
#   {'tag': 'bad',
#    'patterns': ['I am feeling bad', 'No I am sad', 'No'],
#    'responses': ['I hope you will feel better !'],
#    'context': 'feeling'},
#   {'tag': 'actions',
#    'patterns': ['What can you do', 'What can I ask you', 'Can you help me'],
#    'responses': ['I can do a lot of things but here are some of my skills, you can ask me: the capital of a country, its currency and its area. A random number. To calculate a math operation.'],
#    'context': ''},
#   {'tag': 'women',
#    'patterns': ['Are you a girl', 'You are a women'],
#    'responses': ['Sure, I am a women'],
#    'context': ''},
#   {'tag': 'men',
#    'patterns': ['Are you a men', 'Are you a boy'],
#    'responses': ['No, I am a women'],
#    'context': ''},
#   {'tag': 'thanks',
#    'patterns': ['Thank you', 'Thank you very much', 'thanks'],
#    'responses': ['I only do my job️', 'No problem!'],
#    'context': ''},
#   {'tag': 'goodbye',
#    'patterns': ['Goodbye', 'Good afternoon', 'Bye'],
#    'responses': ['Goodbye!', 'See you soon!'],
#    'context': ''},
#   {'tag': 'city',
#    'patterns': ['Where do you live'],
#    'responses': ['I live in a server located in the US!'],
#    'context': ''},
#   {'tag': 'action',
#    'patterns': ['What are you doing'],
#    'responses': ["Actually, I'm chatting with somebody"],
#    'context': ''},
#   {'tag': 'wait',
#    'patterns': ['Can you wait 2 minutes', 'Please wait', 'Wait 2 secs please'],
#    'responses': ['Sure! I wait.'],
#    'context': ''},
#   {'tag': 'still there',
#    'patterns': ['Are you still there?', 'Are you here?'],
#    'responses': ['Of course! Always at your service.'],
#    'context': ''}]}

# %%
#4 Extracting data_X(features) and data_Y(Target)

words = [] #For Bow model/ vocabulary for patterns
classes = [] #For Bow  model/ vocabulary for tags
data_X = [] #For storing each pattern
data_y = [] #For storing tag corresponding to each pattern in data_X

# Iterating over all the intents

for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern) # tokenize each pattern
        words.extend(tokens) #and append tokens to words
        data_X.append(pattern) #appending pattern to data_X
        data_y.append(intent["tag"]) ,# appending the associated tag to each pattern

    # adding the tag to the classes if it's not there already
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()

# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
# 5 Text to Numbers
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(data_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(data_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_Y = np.array(list(training[:, 1]))

# %%
#6 The Neural Network Model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=150, verbose=1)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 128)               7552
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 16848 (65.81 KB)
# Trainable params: 16848 (65.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/150
# 2/2 [==============================] - 1s 13ms/step - loss: 2.8177 - accuracy: 0.0000e+00
# Epoch 2/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.6498 - accuracy: 0.1220
# Epoch 3/150
# 2/2 [==============================] - 0s 9ms/step - loss: 2.4983 - accuracy: 0.1707
# Epoch 4/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4330 - accuracy: 0.2927
# Epoch 5/150
# 2/2 [==============================] - 0s 9ms/step - loss: 2.2001 - accuracy: 0.4878
# Epoch 6/150
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1628 - accuracy: 0.3171
# Epoch 7/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0691 - accuracy: 0.3171
# Epoch 8/150
# 2/2 [==============================] - 0s 7ms/step - loss: 1.6727 - accuracy: 0.4390
# Epoch 9/150
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4295 - accuracy: 0.7073
# Epoch 10/150
# 2/2 [==============================] - 0s 11ms/step - loss: 1.4630 - accuracy: 0.4146
# Epoch 11/150
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3994 - accuracy: 0.4634
# Epoch 12/150
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3268 - accuracy: 0.6098
# Epoch 13/150
# 2/2 [==============================] - 0s 10ms/step - loss: 1.1696 - accuracy: 0.6098
# Epoch 14/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0140 - accuracy: 0.7073
# Epoch 15/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8788 - accuracy: 0.7317
# Epoch 16/150
# 2/2 [==============================] - 0s 10ms/step - loss: 1.0707 - accuracy: 0.5854
# Epoch 17/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7760 - accuracy: 0.7561
# Epoch 18/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7621 - accuracy: 0.7805
# Epoch 19/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7122 - accuracy: 0.7317
# Epoch 20/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7428 - accuracy: 0.7805
# Epoch 21/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5965 - accuracy: 0.7805
# Epoch 22/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6299 - accuracy: 0.7317
# Epoch 23/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4999 - accuracy: 0.9024
# Epoch 24/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6855 - accuracy: 0.7317
# Epoch 25/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4461 - accuracy: 0.8537
# Epoch 26/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3107 - accuracy: 0.9268
# Epoch 27/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5090 - accuracy: 0.8537
# Epoch 28/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4590 - accuracy: 0.8780
# Epoch 29/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4369 - accuracy: 0.8537
# Epoch 30/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5017 - accuracy: 0.8049
# Epoch 31/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3293 - accuracy: 0.9024
# Epoch 32/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3084 - accuracy: 0.8780
# Epoch 33/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2904 - accuracy: 0.9268
# Epoch 34/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3775 - accuracy: 0.9024
# Epoch 35/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4166 - accuracy: 0.8780
# Epoch 36/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3394 - accuracy: 0.9268
# Epoch 37/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3219 - accuracy: 0.9024
# Epoch 38/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2414 - accuracy: 0.9268
# Epoch 39/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2186 - accuracy: 0.9512
# Epoch 40/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4078 - accuracy: 0.8537
# Epoch 41/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1688 - accuracy: 0.9268
# Epoch 42/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1606 - accuracy: 0.9512
# Epoch 43/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2297 - accuracy: 0.9024
# Epoch 44/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2685 - accuracy: 0.9024
# Epoch 45/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2384 - accuracy: 0.9024
# Epoch 46/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1775 - accuracy: 0.9512
# Epoch 47/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3754 - accuracy: 0.8537
# Epoch 48/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1276 - accuracy: 0.9756
# Epoch 49/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1544 - accuracy: 0.9512
# Epoch 50/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1854 - accuracy: 0.9512
# Epoch 51/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1643 - accuracy: 0.9756
# Epoch 52/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1393 - accuracy: 0.9756
# Epoch 53/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1892 - accuracy: 0.9268
# Epoch 54/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3273 - accuracy: 0.8537
# Epoch 55/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2051 - accuracy: 0.9268
# Epoch 56/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2042 - accuracy: 0.9512
# Epoch 57/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1691 - accuracy: 0.8780
# Epoch 58/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1852 - accuracy: 0.9268
# Epoch 59/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2011 - accuracy: 0.9268
# Epoch 60/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2007 - accuracy: 0.9268
# Epoch 61/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2992 - accuracy: 0.9024
# Epoch 62/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2660 - accuracy: 0.8780
# Epoch 63/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0947 - accuracy: 1.0000
# Epoch 64/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1293 - accuracy: 0.9024
# Epoch 65/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1840 - accuracy: 0.9268
# Epoch 66/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1197 - accuracy: 1.0000
# Epoch 67/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2690 - accuracy: 0.9024
# Epoch 68/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2598 - accuracy: 0.9268
# Epoch 69/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1533 - accuracy: 0.9512
# Epoch 70/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1087 - accuracy: 0.9756
# Epoch 71/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 72/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0688 - accuracy: 1.0000
# Epoch 73/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0944 - accuracy: 0.9512
# Epoch 74/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1928 - accuracy: 0.9024
# Epoch 75/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2641 - accuracy: 0.9024
# Epoch 76/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2838 - accuracy: 0.9024
# Epoch 77/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0912 - accuracy: 0.9756
# Epoch 78/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1218 - accuracy: 0.9512
# Epoch 79/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1580 - accuracy: 0.9268
# Epoch 80/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1382 - accuracy: 0.9756
# Epoch 81/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2476 - accuracy: 0.8537
# Epoch 82/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1124 - accuracy: 0.9268
# Epoch 83/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1138 - accuracy: 0.9512
# Epoch 84/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1869 - accuracy: 0.9756
# Epoch 85/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2046 - accuracy: 0.9756
# Epoch 86/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0578 - accuracy: 0.9756
# Epoch 87/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 88/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1485 - accuracy: 0.9512
# Epoch 89/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1475 - accuracy: 0.9268
# Epoch 90/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1274 - accuracy: 0.9756
# Epoch 91/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1447 - accuracy: 0.9268
# Epoch 92/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1475 - accuracy: 0.9024
# Epoch 93/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1347 - accuracy: 0.9512
# Epoch 94/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1074 - accuracy: 0.9512
# Epoch 95/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1724 - accuracy: 0.9512
# Epoch 96/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0721 - accuracy: 0.9756
# Epoch 97/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0899 - accuracy: 0.9512
# Epoch 98/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0504 - accuracy: 0.9756
# Epoch 99/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1552 - accuracy: 0.8780
# Epoch 100/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1355 - accuracy: 0.9268
# Epoch 101/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1253 - accuracy: 0.9512
# Epoch 102/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1152 - accuracy: 0.9756
# Epoch 103/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0959 - accuracy: 0.9756
# Epoch 104/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0657 - accuracy: 1.0000
# Epoch 105/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0865 - accuracy: 0.9756
# Epoch 106/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0891 - accuracy: 0.9268
# Epoch 107/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1313 - accuracy: 0.9512
# Epoch 108/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0739 - accuracy: 0.9512
# Epoch 109/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0866 - accuracy: 0.9756
# Epoch 110/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1481 - accuracy: 0.9756
# Epoch 111/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1140 - accuracy: 0.9268
# Epoch 112/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0855 - accuracy: 0.9756
# Epoch 113/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1774 - accuracy: 0.9268
# Epoch 114/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1234 - accuracy: 0.9512
# Epoch 115/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1142 - accuracy: 0.9756
# Epoch 116/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0857 - accuracy: 0.9756
# Epoch 117/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2114 - accuracy: 0.9512
# Epoch 118/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1696 - accuracy: 0.9512
# Epoch 119/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0667 - accuracy: 0.9512
# Epoch 120/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1041 - accuracy: 0.9512
# Epoch 121/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2611 - accuracy: 0.9024
# Epoch 122/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1401 - accuracy: 0.9756
# Epoch 123/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1080 - accuracy: 0.9512
# Epoch 124/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0582 - accuracy: 0.9756
# Epoch 125/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1917 - accuracy: 0.9512
# Epoch 126/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0856 - accuracy: 0.9512
# Epoch 127/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1854 - accuracy: 0.9268
# Epoch 128/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1347 - accuracy: 0.9268
# Epoch 129/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0674 - accuracy: 0.9512
# Epoch 130/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1900 - accuracy: 0.9512
# Epoch 131/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1399 - accuracy: 0.9268
# Epoch 132/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0765 - accuracy: 0.9756
# Epoch 133/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0623 - accuracy: 0.9756
# Epoch 134/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1002 - accuracy: 0.9512
# Epoch 135/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1357 - accuracy: 0.9268
# Epoch 136/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0687 - accuracy: 0.9756
# Epoch 137/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1164 - accuracy: 0.9512
# Epoch 138/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0964 - accuracy: 0.9512
# Epoch 139/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2443 - accuracy: 0.8780
# Epoch 140/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1790 - accuracy: 0.9268
# Epoch 141/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0931 - accuracy: 0.9512
# Epoch 142/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2130 - accuracy: 0.9268
# Epoch 143/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0898 - accuracy: 0.9756
# Epoch 144/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0927 - accuracy: 0.9756
# Epoch 145/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1317 - accuracy: 0.9512
# Epoch 146/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0734 - accuracy: 0.9756
# Epoch 147/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1011 - accuracy: 0.9512
# Epoch 148/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1123 - accuracy: 0.9512
# Epoch 149/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2826 - accuracy: 0.8780
# Epoch 150/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0977 - accuracy: 0.9756

# %%
#7 Preprocessing the Input

def clean_text(text):
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab):
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0] #Extracting probabilities
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse=True) #Sorting by values of probability in decreasing order
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]]) #Contains labels(tags) for highest probability
  return return_list

def get_response(intents_list, intents_json):
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break
  return result

# %%
.# Interacting with the chatbot
print("Press 0 if you don't want to chat with our ChatBot.")
while True:
    message = input("")
    if message == "0":
      break
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# Press 0 if you don't want to chat with our ChatBot.
# hi how are you
# 1/1 [==============================] - 0s 62ms/step
# Very good and you?
# excellent
# 1/1 [==============================] - 0s 21ms/step
# That is perfect!
# tell me about yourself
# 1/1 [==============================] - 0s 21ms/step
# Sorry! I don't understand.
# how are you?
# 1/1 [==============================] - 0s 22ms/step
# Actually, I'm okay and you?
# i'm doing good
# 1/1 [==============================] - 0s 20ms/step
# That is perfect!
# 0

# %% [markdown]
# #Reference
# - Python Chatbot Project-Learn to build a chatbot from Scratch. (2023, October 26). ProjectPro. https://www.projectpro.io/article/python-chatbot-project-learn-to-build-a-chatbot-from-scratch/429
